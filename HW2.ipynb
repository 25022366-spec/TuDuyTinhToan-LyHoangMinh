# %% [markdown]
# Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diệntíchvàchu vi của nó.

# %%
a,b = map(int, input().split())
print(f"Diện tích là {a*b}, Chu vi là {2*a+2*b}")
# Out:
# Diện tích là 10, Chu vi là 14

# %% [markdown]
# Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó

# %%
r = int(input())
print(f"Diện tích là {3.14*r*r:.2f}, chu vi là {2*3.14*r:.2f}")
# Out:
# Diện tích là 50.24, chu vi là 25.12

# %% [markdown]
# Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểmtra xem nó có thể làđộ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra mànhình.

# %%
import math
a,b,c = map(float,input().split())

if a + b > c and a + c > b and b + c > a:
    cv = a + b + c
    p = cv / 2
    dt = math.sqrt(p * (p - a) * (p - b) * (p - c))
    
    if a == b == c:
        print("Deu")
    elif a == b or b == c or a == c:
        if a*a + b*b == c*c or a*a + c*c == b*b or b*b + c*c == a*a:
            print("Vuong Can")
        else:
            print("Can")
    elif a*a + b*b == c*c or a*a + c*c == b*b or b*b + c*c == a*a:
        print("Vuong")
    else:
        print("Thuong")
    
    print("Chu vi là", round(cv,1))
    print("Diện tích là", round(dt,1))
else:
    print("Khong la ba canh cua mot tam giac")
# Out:
# Vuong
# Chu vi là 12.0
# Diện tích là 6.0

# %% [markdown]
# Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a,b = map(int, input().split())
print("Nghiệm của pt là", -b/a)
# Out:
# Nghiệm của pt là -2.5

# %% [markdown]
# Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a,b,c = map(int, input().split())
delta= b**2 - 4 *a*c
if delta >= 0 :
    print(f"Nghiệm của pt là : x1 = {(- b + (delta)**0.5)/(2*a)} , x2 = {(- b - (delta)**0.5)/(2*a)}")
else : 
    print("pt vô nghiệm")
# Out:
# Nghiệm của pt là : x1 = 2.0 , x2 = 1.0

# %% [markdown]
# Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a,b,c,d= map(float, input().split())
print(max(max(a,b),max(c,d)))
# Out:
# 4.0

# %% [markdown]
# Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a,b,c,d= map(float, input().split())
print(min(min(a,b),min(c,d)))
# Out:
# 1.0

# %% [markdown]
# Bài 8: Giải hệ phương trình tuyến tính:
# ax + by = m
# cx + dy = n

# %%
a,b,m,c,d,n=map(float,input().split())
mau = (a * d - b * c)

if mau != 0:
    y = (a * n - c * m) / mau
    x = (m - b * y) / a
    print("x=",round(x))
    print("y=",round(y))
else:
    if a * n == c * m:
        print("Vo so nghiem")
    else:
        print("Vo nghiem")
# Out:
# x= 4
# y= -1

# %% [markdown]
# Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây.

# %%
x= int(input())
print(f"{x//3600} giờ , {int((x/3600 -int(x//3600))*60)} phút, {x% 60} giây ")
# Out:
# 1 giờ , 20 phút, 36 giây

# %% [markdown]
# Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vàomộtđiểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
a,b, r,x,y=map(float, input().split())
if ((x-a)**2 +(y-b)**2) == r**2 :
    print("Điểm thuộc đường tròn")
else :
    print("Điểm không thuộc đường tròn")
# Out:
# Điểm thuộc đường tròn

# %%
Bài 11: Tính x^y(Với x, y là số thực).

# %%
x,y = map(float, input().split())
print(x**y)
# Out:
# 8.0
